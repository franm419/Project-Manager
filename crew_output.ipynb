# %%
import pandas as pd

# %%
tasks = [{'task_name': 'Create a Blog Series', 'format': 'Blog posts', 'estimated_time_hours': 30.0, 'required_resources': ['Mark Johnson'], 'target_publish_date': None, 'dependencies': ['Research pain points', 'Drafting', 'Reviews', 'SEO Optimization']}, {'task_name': 'Develop Lead Magnet Content', 'format': 'eBook and Checklist', 'estimated_time_hours': 40.0, 'required_resources': ['Sarah Lee'], 'target_publish_date': 'Week 4 of Month 2', 'dependencies': ['Finalized blog series', 'Design assets']}, {'task_name': 'Write Email Nurture Sequence', 'format': 'Email', 'estimated_time_hours': 24.0, 'required_resources': ['Carlos Rivera'], 'target_publish_date': None, 'dependencies': ['Completion of blog content and lead magnet']}, {'task_name': 'Design Promotional Assets for Social Media', 'format': 'Social media graphics/posts', 'estimated_time_hours': 32.0, 'required_resources': ['Priya Desai'], 'target_publish_date': None, 'dependencies': ['Blog series', 'Lead magnet content']}, {'task_name': 'Produce a 2-Minute Explainer Video', 'format': 'Video', 'estimated_time_hours': 40.0, 'required_resources': ['Liam Brown'], 'target_publish_date': 'Week 3 of Month 2', 'dependencies': ['Completion of lead magnet and blog content']}, {'task_name': 'Schedule and Coordinate a Live Webinar', 'format': 'Live webinar', 'estimated_time_hours': 20.0, 'required_resources': ['Sarah Lee', 'Emma Chen'], 'target_publish_date': 'End of Month 2', 'dependencies': ['Finalization of blog content and promotional assets']}, {'task_name': 'Ensure Brand Guidelines Compliance', 'format': 'Review Process', 'estimated_time_hours': 10.0, 'required_resources': ['Sarah Lee'], 'target_publish_date': None, 'dependencies': None}, {'task_name': 'Optimize Blog Posts and Landing Pages for SEO', 'format': 'Written content and site layout', 'estimated_time_hours': 60.0, 'required_resources': ['Mark Johnson'], 'target_publish_date': None, 'dependencies': None}, {'task_name': 'Track Deadlines Using Editorial Calendar', 'format': 'Editorial Calendar (Gantt)', 'estimated_time_hours': 6.0, 'required_resources': ['All content team members'], 'target_publish_date': None, 'dependencies': None}]
df_tasks = pd.DataFrame(tasks)
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_d153e th {
#   font-size: 120%;
# }
# #T_d153e  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_d153e" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d153e_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_d153e_level0_col1" class="col_heading level0 col1" >format</th>
#       <th id="T_d153e_level0_col2" class="col_heading level0 col2" >estimated_time_hours</th>
#       <th id="T_d153e_level0_col3" class="col_heading level0 col3" >required_resources</th>
#       <th id="T_d153e_level0_col4" class="col_heading level0 col4" >target_publish_date</th>
#       <th id="T_d153e_level0_col5" class="col_heading level0 col5" >dependencies</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d153e_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
assignments = [{'task_name': 'Create a Blog Series', 'assigned_to': 'Mark Johnson', 'role': 'SEO Writer', 'start_date': 'Week 1 of Month 1', 'end_date': 'Week 3 of Month 2', 'justification': 'Mark has expertise in SEO writing and is well-suited to understand the pain points of B2B SaaS decision-makers, ensuring quality blog content.'}, {'task_name': 'Develop Lead Magnet Content', 'assigned_to': 'Sarah Lee', 'role': 'Content Strategist', 'start_date': 'Week 3 of Month 1', 'end_date': 'Week 4 of Month 2', 'justification': 'Sarah will leverage her strategic insight to create high-value lead magnets that resonate with the target audience based on the blog series.'}, {'task_name': 'Write Email Nurture Sequence', 'assigned_to': 'Carlos Rivera', 'role': 'Email Marketing Specialist', 'start_date': 'Week 4 of Month 1', 'end_date': 'Week 4 of Month 2', 'justification': 'Carlos specializes in creating engaging email content, ensuring a smooth nurturing process for leads generated from the blog and lead magnet.'}, {'task_name': 'Design Promotional Assets for Social Media', 'assigned_to': 'Priya Desai', 'role': 'Graphic Designer', 'start_date': 'Week 1 of Month 1', 'end_date': 'Ongoing until project completion', 'justification': "Priya's expertise in graphic design will help create visually appealing promotional materials that capture audience attention across various platforms."}, {'task_name': 'Produce a 2-Minute Explainer Video', 'assigned_to': 'Liam Brown', 'role': 'Video Producer', 'start_date': 'Week 1 of Month 1', 'end_date': 'Week 3 of Month 2', 'justification': 'Liam will apply his video production skills to succinctly convey the new features, aligning them with the messaging in blogs and lead magnets.'}, {'task_name': 'Schedule and Coordinate a Live Webinar', 'assigned_to': 'Sarah Lee and Emma Chen', 'role': 'Content Strategist and Social Media Manager', 'start_date': 'Week 1 of Month 2', 'end_date': 'End of Month 2', 'justification': 'Sarah will strategize the content while Emma promotes the webinar effectively on social platforms, leveraging their expertise.'}, {'task_name': 'Ensure Brand Guidelines Compliance', 'assigned_to': 'Sarah Lee', 'role': 'Content Strategist', 'start_date': 'Ongoing', 'end_date': 'Ongoing', 'justification': 'As the strategist, Sarah is best positioned to ensure that all content aligns with brand guidelines and messaging.'}, {'task_name': 'Optimize Blog Posts and Landing Pages for SEO', 'assigned_to': 'Mark Johnson', 'role': 'SEO Writer', 'start_date': 'Post-publication of each blog', 'end_date': 'Ongoing for each blog', 'justification': "Mark's SEO expertise will enhance content visibility and effectiveness post-publication, ensuring maximum reach and engagement."}, {'task_name': 'Track Deadlines Using Editorial Calendar', 'assigned_to': 'All content team members', 'role': 'Various', 'start_date': 'Ongoing', 'end_date': 'Ongoing', 'justification': 'All team members will actively contribute to coordinating timelines, ensuring accountability, and preempting potential blockers.'}]
df_assignments = pd.DataFrame(assignments)
df_assignments.style.set_table_attributes('border="1"').set_caption("Resource Assignments").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_21a82 th {
#   font-size: 120%;
# }
# #T_21a82  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_21a82" border="1">
#   <caption>Resource Assignments</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21a82_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_21a82_level0_col1" class="col_heading level0 col1" >assigned_to</th>
#       <th id="T_21a82_level0_col2" class="col_heading level0 col2" >role</th>
#       <th id="T_21a82_level0_col3" class="col_heading level0 col3" >start_date</th>
#       <th id="T_21a82_level0_col4" class="col_heading level0 col4" >end_date</th>
#       <th id="T_21a82_level0_col5" class="col_heading level0 col5" >justification</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21a82_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_21a82_row0_col0" class="data row0 col0" >Create a Blog Series</td>
# ...

# %%
milestones = [{'milestone_name': 'Initial Blog Series Completed', 'tasks': ['Create a Blog Series']}, {'milestone_name': 'Lead Magnet Content Completed', 'tasks': ['Develop Lead Magnet Content']}, {'milestone_name': 'Email Nurture Sequence Completed', 'tasks': ['Write Email Nurture Sequence']}, {'milestone_name': 'Promotional Assets Ready', 'tasks': ['Design Promotional Assets for Social Media']}, {'milestone_name': 'Explainer Video Completed', 'tasks': ['Produce a 2-Minute Explainer Video']}, {'milestone_name': 'Webinar Scheduled', 'tasks': ['Schedule and Coordinate a Live Webinar']}]
df_milestones = pd.DataFrame(milestones)
df_milestones.style.set_table_attributes('border="1"').set_caption("Milestones").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_87ec7 th {
#   font-size: 120%;
# }
# #T_87ec7  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_87ec7" border="1">
#   <caption>Milestones</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87ec7_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_87ec7_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87ec7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_87ec7_row0_col0" class="data row0 col0" >Initial Blog Series Completed</td>
#       <td id="T_87ec7_row0_col1" class="data row0 col1" >['Create a Blog Series']</td>
#     </tr>
#     <tr>
#       <th id="T_87ec7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_87ec7_row1_col0" class="data row1 col0" >Lead Magnet Content Completed</td>
# ...

# %%
print("📅 Content Calendar Summary:")
print("""Weekly Gantt chart tracking tasks across the content marketing campaign.""")
# Out:
# 📅 Content Calendar Summary:
# Weekly Gantt chart tracking tasks across the content marketing campaign.
